# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Imports

# %%
from object_detection_sabine import all_xml_to_df, annotation_check, annotation_overview, plot_sample_bndbox

# %% [markdown]
# ## Annotation check

# %%
annotation_check('TensorFlow/workspace/training_products_shelf/images/all_label')
# Out:
# All jpg-files have an xml-file with the same name.

# %% [markdown]
# ## Annotation Overview
#
# Now we load all xml-files with the annoations into a Pandas DataFrame to explore the images. The indices refer to the objects in the images.

# %%
df = all_xml_to_df('TensorFlow/workspace/training_products_shelf/images/all_label')
df.head()
# Out:
#              name xmin xmax ymin ymax   filename width height depth
# object1  product1   86  105  168  200  shop1.jpg   282    500     3
# object2  product1  110  130  168  199  shop1.jpg   282    500     3
# object3  product1   90  108  211  243  shop1.jpg   282    500     3
# object4  product1  112  131  212  243  shop1.jpg   282    500     3
# object5  product1   92  111  255  284  shop1.jpg   282    500     3

# %%
annotation_overview(df)
# Out:
# There are 569 images.
#
# The images are of the following sizes:
# 375 x 281
# 375 x 500
# 500 x 282
# 281 x 375
# 282 x 500
# 225 x 500
# 500 x 225
#
# The labels are:
# product1
# product2
# design1
# design2
# design3
# design4

# %% [markdown]
# ## Random sample of images

# %%
plot_sample_bndbox('TensorFlow/workspace/training_products_shelf/images/all_label', 12, df)
